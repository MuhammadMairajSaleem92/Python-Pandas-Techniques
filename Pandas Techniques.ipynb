# %% [markdown]
# ### Loading and assessing data

# %%
# first import the libraries
import pandas as pd

# %%
# import the World Cup T20 data
data = pd.read_csv(r'C:\Users\Mairaj-PC\Desktop\worldt20_data.csv')
data.head()
# Out:
#   Unnamed: 0       team_1       team_2        stage  Winner_toss  \
# 0    Match_1    Australia  SouthAfrica  Group_stage    Australia
# 1    Match_2      England      Windies  Group_stage      England
# 2    Match_3     Srilanka   Bangladesh  Group_stage     Srilanka
# 3    Match_4     Pakistan        India  Group_stage     Pakistan
# 4    Match_5  Afghanistan     Scotland  Group_stage  Afghanistan
#
#   Toss_descision       time      venue  avg_temperature       best_bowler  \
# 0       Fielding  afternoon  Abu_Dhabi               30    Josh_Hazlewood
# 1       Fielding    evening      Dubai               33       Adil_Rashid
# 2       Fielding  afternoon    Sharjah               34  Shakib_al_Hassan
# 3       Fielding    evening      Dubai               34      Shaheen_shah
# 4        Batting    evening    Sharjah               33  Mujeeb_ur_Rehman
#
#    ... best_bowler_country        best_batter  batting_hand  \
# 0  ...           Australia      Aiden_Markram         Right
# 1  ...             England        Jos_Buttler         Right
# 2  ...          Bangladesh   Charith_Asalanka          Left
# 3  ...            Pakistan    Muhammad_Rizwan         Right
# 4  ...         Afghanistan  Najibullah_Zadran          Left
#
#    high_indvidual_scores strike_rate best_batter_team target  target_achieved  \
# 0                     40      111.10      SouthAfrica    119                1
# 1                     24      109.10          England     56                1
# 2                     80      163.20         Srilanka    172                1
# 3                     79      143.60         Pakistan    152                1
# 4                     59      173.53      Afghanistan    191                0
#
#    Player_of_the_match       Winner
# 0       Josh_Hazlewood    Australia
# 1            Moeen_Ali      England
# 2     Charith_Asalanka     Srilanka
# 3         Shaheen_shah     Pakistan
# 4     Mujeeb_ur_Rehman  Afghanistan
#
# [5 rows x 24 columns]

# %%
# check the description of data in detail
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               33 non-null     object
#  1   team_1                   33 non-null     object
#  2   team_2                   33 non-null     object
#  3   stage                    33 non-null     object
#  4   Winner_toss              33 non-null     object
#  5   Toss_descision           33 non-null     object
#  6   time                     33 non-null     object
#  7   venue                    33 non-null     object
#  8   avg_temperature          33 non-null     int64
#  9   best_bowler              33 non-null     object
#  10  bowling_arm              33 non-null     object
#  11  bowling_style            33 non-null     object
#  12  most_individual_wickets  33 non-null     int64
#  13  economy                  33 non-null     float64
#  14  best_bowler_country      33 non-null     object
#  15  best_batter              33 non-null     object
#  16  batting_hand             33 non-null     object
#  17  high_indvidual_scores    33 non-null     int64
#  18  strike_rate              33 non-null     float64
#  19  best_batter_team         33 non-null     object
#  20  target                   33 non-null     int64
#  21  target_achieved          33 non-null     int64
#  22  Player_of_the_match      33 non-null     object
#  23  Winner                   33 non-null     object
# dtypes: float64(2), int64(5), object(17)
# memory usage: 6.3+ KB

# %%
# check the basic statistical summary of data
data.describe()
# Out:
#        avg_temperature  most_individual_wickets    economy  \
# count        33.000000                33.000000  33.000000
# mean         29.272727                 2.878788   5.215758
# std           2.577217                 0.892944   2.187966
# min          20.000000                 1.000000   0.900000
# 25%          28.000000                 2.000000   4.000000
# 50%          29.000000                 3.000000   4.800000
# 75%          30.000000                 3.000000   6.250000
# max          34.000000                 5.000000  12.000000
#
#        high_indvidual_scores  strike_rate      target  target_achieved
# count              33.000000    33.000000   33.000000        33.000000
# mean               62.393939   152.402121  146.606061         0.696970
# std                20.135385    33.999070   37.136521         0.466694
# min                24.000000    97.060000   56.000000         0.000000
# 25%                45.000000   136.360000  125.000000         0.000000
# 50%                65.000000   153.190000  152.000000         1.000000
# 75%                79.000000   162.900000  173.000000         1.000000
# max               101.000000   263.160000  211.000000         1.000000

# %% [markdown]
# ### Sorting, counting and applying a condition to data

# %%
# sort the data from highest to lowest target of each match
data.sort_values('target', ascending = False).head(3)
# Out:
#    Unnamed: 0       team_1       team_2        stage  Winner_toss  \
# 20   Match_21        India  Afghanistan  Group_stage  Afghanistan
# 4     Match_5  Afghanistan     Scotland  Group_stage  Afghanistan
# 18   Match_19     Pakistan      Namibia  Group_stage     Pakistan
#
#    Toss_descision     time      venue  avg_temperature       best_bowler  ...  \
# 20       Fielding  evening  Abu_Dhabi               29    Mohammed Shami  ...
# 4         Batting  evening    Sharjah               33  Mujeeb_ur_Rehman  ...
# 18        Batting  evening  Abu_Dhabi               29        Imad_wasim  ...
#
#    best_bowler_country        best_batter  batting_hand  \
# 20               India       Rohit_Sharma         Right
# 4          Afghanistan  Najibullah_Zadran          Left
# 18            Pakistan    Muhammad_Rizwan         Right
#
#     high_indvidual_scores strike_rate best_batter_team target  \
# 20                     74      157.45            India    211
# 4                      59      173.53      Afghanistan    191
# 18                     79      158.00         Pakistan    190
#
#     target_achieved  Player_of_the_match       Winner
# 20                0         Rohit_Sharma        India
# 4                 0     Mujeeb_ur_Rehman  Afghanistan
# 18                0      Muhammad_Rizwan     Pakistan
#
# [3 rows x 24 columns]

# %%
# sorting with multiple columns (lowest by target and highest by temperature)
data.sort_values(['target', 'avg_temperature'], ascending = [True, False]).head(3)
# Out:
#    Unnamed: 0       team_1      team_2        stage  Winner_toss  \
# 1     Match_2      England     Windies  Group_stage      England
# 21   Match_22    Australia  Bangladesh  Group_stage    Australia
# 17   Match_18  SouthAfrica  Bangladesh  Group_stage  SouthAfrica
#
#    Toss_descision       time      venue  avg_temperature    best_bowler  ...  \
# 1        Fielding    evening      Dubai               33    Adil_Rashid  ...
# 21       Fielding  afternoon      Dubai               29     Adam_Zampa  ...
# 17       Fielding  afternoon  Abu_Dhabi               30  Anrich_Nortje  ...
#
#    best_bowler_country    best_batter  batting_hand  high_indvidual_scores  \
# 1              England    Jos_Buttler         Right                     24
# 21           Australia    Aaron_Finch         Right                     40
# 17         SouthAfrica  Temaba_Bavuma         Right                     31
#
#    strike_rate best_batter_team target  target_achieved  Player_of_the_match  \
# 1        109.1          England     56                1            Moeen_Ali
# 21       200.0        Australia     74                1           Adam_Zampa
# 17       110.7      SouthAfrica     85                1        Kagiso_Rabada
#
#          Winner
# 1       England
# 21    Australia
# 17  SouthAfrica
#
# [3 rows x 24 columns]

# %%
# find the player those have 50 plus individual scores and target not achieved
data[(data['high_indvidual_scores'] > 50) & (data['target_achieved'] == 0)].head()
# Out:
#    Unnamed: 0       team_1       team_2        stage  Winner_toss  \
# 4     Match_5  Afghanistan     Scotland  Group_stage  Afghanistan
# 16   Match_17      England     Srilanka  Group_stage     Srilanka
# 18   Match_19     Pakistan      Namibia  Group_stage     Pakistan
# 19   Match_20  New_Zealand     ScotLand  Group_stage  New_Zealand
# 20   Match_21        India  Afghanistan  Group_stage  Afghanistan
#
#    Toss_descision       time      venue  avg_temperature        best_bowler  \
# 4         Batting    evening    Sharjah               33   Mujeeb_ur_Rehman
# 16       Fielding    evening    Sharjah               28  Wanindu_Hasaranga
# 18        Batting    evening  Abu_Dhabi               29         Imad_wasim
# 19       Fielding  afternoon      Dubai               29     Safyaan_Sharif
# 20       Fielding    evening  Abu_Dhabi               29     Mohammed Shami
#
#     ... best_bowler_country        best_batter  batting_hand  \
# 4   ...         Afghanistan  Najibullah_Zadran          Left
# 16  ...            Srilanka        Jos_Buttler         Right
# 18  ...            Pakistan    Muhammad_Rizwan         Right
# 19  ...            ScotLand     Martin_Guptill         Right
# 20  ...               India       Rohit_Sharma         Right
#
#     high_indvidual_scores strike_rate best_batter_team target  \
# 4                      59      173.53      Afghanistan    191
# 16                    101      150.75          England    164
# 18                     79      158.00         Pakistan    190
# 19                     93      166.07      New_Zealand    173
# 20                     74      157.45            India    211
#
#     target_achieved  Player_of_the_match       Winner
# 4                 0     Mujeeb_ur_Rehman  Afghanistan
# 16                0          Jos_Buttler      England
# 18                0      Muhammad_Rizwan     Pakistan
# 19                0       Martin_Guptill  New_Zealand
# 20                0         Rohit_Sharma        India
#
# [5 rows x 24 columns]

# %%
# find the count of matches in each venue
data['venue'].value_counts()
# Out:
# Dubai        13
# Abu_Dhabi    11
# Sharjah       9
# Name: venue, dtype: int64

# %%
# find the most number of wins by each country
most_wins = data['Winner'].value_counts()
most_wins.head(4)
# Out:
# Australia      6
# New_Zealand    5
# Pakistan       5
# SouthAfrica    4
# Name: Winner, dtype: int64

# %% [markdown]
# ### Group Summary Statistics from data (groupby)

# %%
# average temperatue in each venue
data.groupby('venue')['avg_temperature'].mean()
# Out:
# venue
# Abu_Dhabi    28.363636
# Dubai        29.769231
# Sharjah      29.666667
# Name: avg_temperature, dtype: float64

# %%
# find the summary statistics of strike rate and target for each winning country
data.groupby('Winner')[['strike_rate', 'target']].agg([min, max])
# Out:
#             strike_rate         target
#                     min     max    min  max
# Winner
# Afghanistan      136.36  173.53    161  191
# Australia        111.10  200.00     74  177
# England          109.10  221.80     56  164
# India            151.35  263.16     86  211
# Namibia          162.90  162.90    110  110
# New_Zealand      140.00  185.71    111  173
# Pakistan          97.06  158.00    135  190
# SouthAfrica      110.70  160.00     85  190
# Srilanka         150.00  163.20    172  190
# Windies          102.30  102.30    140  140

# %%
# find the most economical bowler 
data.groupby('best_bowler')['economy'].mean().sort_values().head(3)
# Out:
# best_bowler
# Adil_Rashid      0.90
# Hamid_Hassan     2.25
# Anrich_Nortje    2.40
# Name: economy, dtype: float64

# %% [markdown]
# ### Indexing and Slicing

# %%
# make the index set to winner toss to see which have more toss win
new_data = data.set_index('Winner_toss')
new_data.head(3)
# Out:
#             Unnamed: 0     team_1       team_2        stage Toss_descision  \
# Winner_toss
# Australia      Match_1  Australia  SouthAfrica  Group_stage       Fielding
# England        Match_2    England      Windies  Group_stage       Fielding
# Srilanka       Match_3   Srilanka   Bangladesh  Group_stage       Fielding
#
#                   time      venue  avg_temperature       best_bowler  \
# Winner_toss
# Australia    afternoon  Abu_Dhabi               30    Josh_Hazlewood
# England        evening      Dubai               33       Adil_Rashid
# Srilanka     afternoon    Sharjah               34  Shakib_al_Hassan
#
#             bowling_arm  ... best_bowler_country       best_batter  \
# Winner_toss              ...
# Australia         Right  ...           Australia     Aiden_Markram
# England           Right  ...             England       Jos_Buttler
# Srilanka           Left  ...          Bangladesh  Charith_Asalanka
#
#              batting_hand high_indvidual_scores strike_rate best_batter_team  \
# Winner_toss
# Australia           Right                    40       111.1      SouthAfrica
# England             Right                    24       109.1          England
# Srilanka             Left                    80       163.2         Srilanka
#
#              target  target_achieved Player_of_the_match     Winner
# Winner_toss
# Australia       119                1      Josh_Hazlewood  Australia
# England          56                1           Moeen_Ali    England
# Srilanka        172                1    Charith_Asalanka   Srilanka
#
# [3 rows x 23 columns]

# %%
# subset the new data with few columns
selective_new_data = new_data[['team_2', 'stage']]

# print result of Pakistan
print(selective_new_data.loc['Pakistan'])
# Out:
#                   team_2        stage
# Winner_toss
# Pakistan           India  Group_stage
# Pakistan     New_Zealand  Group_stage
# Pakistan         Namibia  Group_stage
# Pakistan        ScotLand  Group_stage

# %%
# we also use indexing by number using .iloc[]
# See the match 15 to 18
data.iloc[14:18,:5]
# Out:
#    Unnamed: 0       team_1      team_2        stage  Winner_toss
# 14   Match_15  Afghanistan     Namibia  Group_stage  Afghanistan
# 15   Match_16  New_Zealand       India  Group_stage  New_Zealand
# 16   Match_17      England    Srilanka  Group_stage     Srilanka
# 17   Match_18  SouthAfrica  Bangladesh  Group_stage  SouthAfrica

# %% [markdown]
# ### Plotting with Pandas

# %%
# Create a vraible most_wins that show number of matches won by every team
# lets see result with bar plot
most_wins.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
# lets find a relation with strike rate and target set in those game when target is chased
target_chased = data[data['target_achieved'] == 1]

# for this, we use scatter plot
target_chased.plot(x = 'target', y = 'strike_rate', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='target', ylabel='strike_rate'>
